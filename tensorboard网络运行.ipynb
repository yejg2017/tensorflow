# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# %%
#载入数据
mnist=input_data.read_data_sets('MNIST_data',one_hot=True)

#每个批次的大小
batch_size=100
#计算多少个批次
n_batch=mnist.train.num_examples//batch_size

#定义一个函数
def variable_summaries(var):
    with tf.name_scope('summaries'):
        mean=tf.reduce_mean(var)
        tf.summary.scalar('mean',mean)#记录平均值
        with tf.name_scope('stddev'):
            stddev=tf.sqrt(tf.reduce_mean(tf.square(var-mean)))
        tf.summary.scalar('stddev',stddev)
        tf.summary.scalar('max',tf.reduce_max(var))
        tf.summary.scalar('min',tf.reduce_min(var))
        tf.summary.histogram('histogram',var)

            
#定义两个占位符

with tf.name_scope('input'):
    x=tf.placeholder(shape=[None,784],dtype=tf.float32,name='x_input')
    y=tf.placeholder(shape=[None,10],dtype=tf.float32,name='y_input')
     
#创建一个简单的神经网络
with tf.name_scope('layer'):
    with tf.name_scope('weight'):
        w=tf.Variable(tf.zeros(shape=[784,10]))
        variable_summaries(w)
    with tf.name_scope('biases'):
        b=tf.Variable(tf.zeros(shape=[10]))
        variable_summaries(b)
    with tf.name_scope('preidicton'):
        prediction=tf.nn.softmax(tf.matmul(x,w)+b)
        
#二次代价函数
with tf.name_scope('train'):
    with tf.name_scope('loss'):
       loss=tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
                   labels=y,logits=prediction))
       tf.summary.scalar('loss',loss)
    with tf.name_scope('train_step'):
       #使用梯度下降法
       train_step=tf.train.GradientDescentOptimizer(0.2).minimize(loss)

#初始化变量
init=tf.global_variables_initializer()

#结果存在一个bool列表中
with tf.name_scope('accuracy'):
    with tf.name_scope('correct_prediction'):
         correct_prediction=tf.equal(tf.argmax(y,1),tf.argmax(prediction,1))
    
    with tf.name_scope('accuracy'):
         #求准确率
         accuracy=tf.reduce_mean(tf.cast(correct_prediction,dtype=tf.float32))
         tf.summary.scalar('accuracy',accuracy)

##合并所有的summary
merged=tf.summary.merge_all()
            
with tf.Session() as sess:
    sess.run(init)
    writer=tf.summary.FileWriter('logs/',sess.graph) #将图写入该路径中
    for epoch in range(101):
        for batch in range(n_batch):
            batch_xs,batch_ys=mnist.train.next_batch(batch_size)
            summary,_=sess.run([merged,train_step],feed_dict={
                                         x:batch_xs,
                                         y:batch_ys
            })  #merged一起训练
        writer.add_summary(summary,epoch)  #写入图中
        acc=sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels})
        print('Iter'+str(epoch)+',Testing Accuracy:'+str(acc)) 
        # $tensorboard --logdir=logs
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter0,Testing Accuracy:0.8234
# Iter1,Testing Accuracy:0.8773
# Iter2,Testing Accuracy:0.9004
# Iter3,Testing Accuracy:0.9046
# Iter4,Testing Accuracy:0.9079
# Iter5,Testing Accuracy:0.9109
# Iter6,Testing Accuracy:0.9113
# Iter7,Testing Accuracy:0.9127
# Iter8,Testing Accuracy:0.9156
# Iter9,Testing Accuracy:0.9155
# Iter10,Testing Accuracy:0.918
# Iter11,Testing Accuracy:0.9187
# Iter12,Testing Accuracy:0.9185
# Iter13,Testing Accuracy:0.9196
# Iter14,Testing Accuracy:0.919
# Iter15,Testing Accuracy:0.9207
# Iter16,Testing Accuracy:0.9212
# Iter17,Testing Accuracy:0.9204
# Iter18,Testing Accuracy:0.9211
# Iter19,Testing Accuracy:0.9215
# Iter20,Testing Accuracy:0.9223
# Iter21,Testing Accuracy:0.9224
# Iter22,Testing Accuracy:0.9219
# Iter23,Testing Accuracy:0.9232
# Iter24,Testing Accuracy:0.9227
# Iter25,Testing Accuracy:0.9237
# Iter26,Testing Accuracy:0.9224
# Iter27,Testing Accuracy:0.9236
# Iter28,Testing Accuracy:0.9234
# Iter29,Testing Accuracy:0.9248
# Iter30,Testing Accuracy:0.9245
# Iter31,Testing Accuracy:0.9246
# Iter32,Testing Accuracy:0.9247
# Iter33,Testing Accuracy:0.9248
# Iter34,Testing Accuracy:0.9244
# Iter35,Testing Accuracy:0.9247
# Iter36,Testing Accuracy:0.9252
# Iter37,Testing Accuracy:0.9256
# Iter38,Testing Accuracy:0.9256
# Iter39,Testing Accuracy:0.9249
# Iter40,Testing Accuracy:0.9257
# Iter41,Testing Accuracy:0.9266
# Iter42,Testing Accuracy:0.9257
# Iter43,Testing Accuracy:0.9264
# Iter44,Testing Accuracy:0.9263
# Iter45,Testing Accuracy:0.9258
# Iter46,Testing Accuracy:0.9255
# Iter47,Testing Accuracy:0.9268
# Iter48,Testing Accuracy:0.9272
# Iter49,Testing Accuracy:0.9267
# Iter50,Testing Accuracy:0.9268
# Iter51,Testing Accuracy:0.9274
# Iter52,Testing Accuracy:0.9272
# Iter53,Testing Accuracy:0.9275
# Iter54,Testing Accuracy:0.9272
# Iter55,Testing Accuracy:0.9275
# Iter56,Testing Accuracy:0.927
# Iter57,Testing Accuracy:0.9279
# Iter58,Testing Accuracy:0.9263
# Iter59,Testing Accuracy:0.9271
# Iter60,Testing Accuracy:0.928
# Iter61,Testing Accuracy:0.9278
# Iter62,Testing Accuracy:0.9284
# Iter63,Testing Accuracy:0.9276
# Iter64,Testing Accuracy:0.9283
# Iter65,Testing Accuracy:0.9276
# Iter66,Testing Accuracy:0.9283
# Iter67,Testing Accuracy:0.9282
# Iter68,Testing Accuracy:0.9285
# Iter69,Testing Accuracy:0.9276
# Iter70,Testing Accuracy:0.9285
# Iter71,Testing Accuracy:0.9283
# Iter72,Testing Accuracy:0.9282
# Iter73,Testing Accuracy:0.929
# Iter74,Testing Accuracy:0.9292
# Iter75,Testing Accuracy:0.9287
# Iter76,Testing Accuracy:0.9283
# Iter77,Testing Accuracy:0.928
# Iter78,Testing Accuracy:0.9279
# Iter79,Testing Accuracy:0.9283
# Iter80,Testing Accuracy:0.9278
# Iter81,Testing Accuracy:0.9283
# Iter82,Testing Accuracy:0.9287
# Iter83,Testing Accuracy:0.9279
# Iter84,Testing Accuracy:0.9293
# Iter85,Testing Accuracy:0.9284
# Iter86,Testing Accuracy:0.9281
# Iter87,Testing Accuracy:0.9279
# Iter88,Testing Accuracy:0.9284
# Iter89,Testing Accuracy:0.9284
# Iter90,Testing Accuracy:0.9279
# Iter91,Testing Accuracy:0.9285
# Iter92,Testing Accuracy:0.9285
# Iter93,Testing Accuracy:0.9286
# Iter94,Testing Accuracy:0.9292
# Iter95,Testing Accuracy:0.9283
# Iter96,Testing Accuracy:0.9287
# Iter97,Testing Accuracy:0.9289
# Iter98,Testing Accuracy:0.9286
# Iter99,Testing Accuracy:0.9289
# Iter100,Testing Accuracy:0.9282
